# %% [markdown]
# # Import Data

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
import pickle
import time
import os.path

# %%
# group = pd.read_csv('Group_xx.csv') # format of output
train_raw = pd.read_csv('train.csv')
test_raw = pd.read_csv('test.csv')
validation_raw = pd.read_csv('validation.csv')

# %%
def down_sample_train(train, n = 1):
    # down sample click = 0 data so as 'len(click = 0) = n* len(click = 1)'
    
    click_0 = train[ train.click ==0 ]
    click_1 = train[ train.click ==1 ]
    
    np.random.seed(666)
    sampled_click_index = np.random.choice( click_0.index, len(click_1)*n, replace = False)
    sampled_click_df = click_0.loc[ sampled_click_index ]
    
    new_train = pd.concat([sampled_click_df, click_1], axis = 0)
    
    return new_train
    

def split_useragent( df ):
    # split column useragent into 'OS' and 'browser'
    
    user_agent = df['useragent']
    OS = [agent.split('_')[0] for agent in user_agent]
    browser = [agent.split('_')[1] for agent in user_agent]
    df['OS'] = OS
    df['browser'] = browser
    df = pd.concat([df, pd.get_dummies( df['OS'], prefix = 'OS')], axis = 1)
    df = pd.concat([df, pd.get_dummies( df['browser'], prefix = 'browser')], axis = 1)
    df = df.drop(['useragent','OS', 'browser'], axis = 1)
    
    return df 


def split_usertag(df):
    # split user tags to dummy variables 
    
    splitting_tags = df['usertag'].str.get_dummies(sep=',')
    df = pd.concat([df, splitting_tags], axis = 1)
    df = df.drop('usertag', axis = 1)
    
    return df

def create_dummies(df, dummy_variables):
    # one-hot encoding for categorical variables
    
    for feat in dummy_variables:
        
        df = pd.concat([df, pd.get_dummies(df[feat], prefix=feat)],axis=1)
        df = df.drop(feat,axis=1)
    
    return df

def preprocess(df, downSample = False):
    # pipeline for sampling data and transform features 
    
    if downSample:
        df = down_sample_train(df)
    
    # extract OS and browser from useragent
    df = split_useragent(df)
    
    # compute slotsize
    df['slotsize'] = df['slotwidth'] * df['slotheight']

    df = split_usertag(df)

    df = df.drop(['bidid', 'userid','IP','domain','url', 'urlid', 'slotid','slotformat','creative',\
                                 'keypage', 'slotwidth', 'slotheight'], axis = 1)
    
    # create dummies
    dummy_variables = ['region', 'city', 'adexchange', 'slotvisibility', 'advertiser']
    df = create_dummies(df, dummy_variables)
    
    return df

def remove_non_seen_cols(train,df, isTest = False):
    # due to sampling, many values may not seen before, only kept the seen data
    
    missing_col = np.setdiff1d(np.array(train.columns), np.array(df.columns))
    
    for col in missing_col:
        df[col] = 0
    
    if isTest:
        df = df[train.drop(['bidprice', 'click', 'payprice'], axis = 1).columns]
    else:
        df = df[train.columns]
    
    return df

# %%
class Time_Tracking():
    
    start_time = None
    
    def start_tracking(self):
        
        self.start_time = time.time()
    
    def stop_tracking(self):
        
        print("Time used:", round(((time.time() - self.start_time)/60),2), ' minutes')

# %%
t = Time_Tracking()
t.start_tracking()

train = preprocess(train_raw, downSample = True)
valid = preprocess(validation_raw)
valid = remove_non_seen_cols( train, valid )
test = preprocess(test_raw)
test = remove_non_seen_cols( train, test, isTest=True)

t.stop_tracking()
# Out:
# Time used: 1.03  minutes

# %% [markdown]
# # Save to pickle

# %%
n_bytes = 2**31
max_bytes = 2**31 - 1


def write_to_pickle(file_path, data):

    bytes_out = pickle.dumps(data)
    with open(file_path, 'wb') as f_out:
        for idx in range(0, n_bytes, max_bytes):
            f_out.write(bytes_out[idx:idx+max_bytes])

write_to_pickle('train_df_after_preprocessing.pkl', train)
write_to_pickle('valid_df_after_preprocessing.pkl', valid)
write_to_pickle('test_df_after_preprocessing.pkl', test)

# %% [markdown]
# # How to load pickle

# %%
def load_pickle(file_path):
    bytes_in = bytearray(0)
    input_size = os.path.getsize(file_path)
    with open(file_path, 'rb') as f_in:
        for _ in range(0, input_size, max_bytes):
            bytes_in += f_in.read(max_bytes)
    
    return pickle.loads(bytes_in)

# %%
#  read pickle        
train_ = load_pickle('train_df_after_preprocessing.pkl')
test_ = load_pickle('test_df_after_preprocessing.pkl')
valid_ = load_pickle('valid_df_after_preprocessing.pkl')

# %%
if_train_valid = (train == train_)
if_valid_valid = (valid == valid_)
if_test_valid = (test == test_)

print(if_train_valid)
print(if_valid_valid)
print(if_test_valid)
# Out:
#          click  weekday  hour  slotprice  bidprice  payprice  OS_android  \
# 367179    True     True  True       True      True      True        True
# 1858024   True     True  True       True      True      True        True
# 54000     True     True  True       True      True      True        True
# 1073484   True     True  True       True      True      True        True
# 1185737   True     True  True       True      True      True        True
# 115944    True     True  True       True      True      True        True
# 592831    True     True  True       True      True      True        True
# 2080586   True     True  True       True      True      True        True
# 1860949   True     True  True       True      True      True        True
# 1724755   True     True  True       True      True      True        True
# 1630318   True     True  True       True      True      True        True
# 2088154   True     True  True       True      True      True        True
# 2004240   True     True  True       True      True      True        True
# 1617647   True     True  True       True      True      True        True
# 2397981   True     True  True       True      True      True        True
# 442932    True     True  True       True      True      True        True
# 350514    True     True  True       True      True      True        True
# 1278275   True     True  True       True      True      True        True
# 949163    True     True  True       True      True      True        True
# 474078    True     True  True       True      True      True        True
# 583089    True     True  True       True      True      True        True
# 868516    True     True  True       True      True      True        True
# 1899600   True     True  True       True      True      True        True
# 1208562   True     True  True       True      True      True        True
# 1370098   True     True  True       True      True      True        True
# 719393    True     True  True       True      True      True        True
# 2377190   True     True  True       True      True      True        True
# 2097978   True     True  True       True      True      True        True
# 1233293   True     True  True       True      True      True        True
# 749998    True     True  True       True      True      True        True
# ...        ...      ...   ...        ...       ...       ...         ...
# 2380677   True     True  True       True      True      True        True
# 2381907   True     True  True       True      True      True        True
# 2382324   True     True  True       True      True      True        True
# 2385688   True     True  True       True      True      True        True
# 2385798   True     True  True       True      True      True        True
# 2387011   True     True  True       True      True      True        True
# 2387360   True     True  True       True      True      True        True
# 2389704   True     True  True       True      True      True        True
# 2391471   True     True  True       True      True      True        True
# 2391894   True     True  True       True      True      True        True
# 2393079   True     True  True       True      True      True        True
# 2395842   True     True  True       True      True      True        True
# 2399896   True     True  True       True      True      True        True
# 2400875   True     True  True       True      True      True        True
# 2403309   True     True  True       True      True      True        True
# 2404304   True     True  True       True      True      True        True
# 2404359   True     True  True       True      True      True        True
# 2405586   True     True  True       True      True      True        True
# 2406338   True     True  True       True      True      True        True
# 2412602   True     True  True       True      True      True        True
# 2415833   True     True  True       True      True      True        True
# 2415911   True     True  True       True      True      True        True
# 2416561   True     True  True       True      True      True        True
# 2417205   True     True  True       True      True      True        True
# 2418891   True     True  True       True      True      True        True
# 2419465   True     True  True       True      True      True        True
# 2422126   True     True  True       True      True      True        True
# 2422921   True     True  True       True      True      True        True
# 2425243   True     True  True       True      True      True        True
# 2428854   True     True  True       True      True      True        True
#
#          OS_ios  OS_linux  OS_mac       ...         slotvisibility_ThirdView  \
# 367179     True      True    True       ...                             True
# 1858024    True      True    True       ...                             True
# 54000      True      True    True       ...                             True
# 1073484    True      True    True       ...                             True
# 1185737    True      True    True       ...                             True
# 115944     True      True    True       ...                             True
# 592831     True      True    True       ...                             True
# 2080586    True      True    True       ...                             True
# 1860949    True      True    True       ...                             True
# 1724755    True      True    True       ...                             True
# 1630318    True      True    True       ...                             True
# 2088154    True      True    True       ...                             True
# 2004240    True      True    True       ...                             True
# 1617647    True      True    True       ...                             True
# 2397981    True      True    True       ...                             True
# 442932     True      True    True       ...                             True
# 350514     True      True    True       ...                             True
# 1278275    True      True    True       ...                             True
# 949163     True      True    True       ...                             True
# 474078     True      True    True       ...                             True
# 583089     True      True    True       ...                             True
# 868516     True      True    True       ...                             True
# 1899600    True      True    True       ...                             True
# 1208562    True      True    True       ...                             True
# 1370098    True      True    True       ...                             True
# 719393     True      True    True       ...                             True
# 2377190    True      True    True       ...                             True
# 2097978    True      True    True       ...                             True
# 1233293    True      True    True       ...                             True
# 749998     True      True    True       ...                             True
# ...         ...       ...     ...       ...                              ...
# 2380677    True      True    True       ...                             True
# 2381907    True      True    True       ...                             True
# 2382324    True      True    True       ...                             True
# 2385688    True      True    True       ...                             True
# 2385798    True      True    True       ...                             True
# 2387011    True      True    True       ...                             True
# 2387360    True      True    True       ...                             True
# 2389704    True      True    True       ...                             True
# 2391471    True      True    True       ...                             True
# 2391894    True      True    True       ...                             True
# 2393079    True      True    True       ...                             True
# 2395842    True      True    True       ...                             True
# 2399896    True      True    True       ...                             True
# 2400875    True      True    True       ...                             True
# 2403309    True      True    True       ...                             True
# 2404304    True      True    True       ...                             True
# 2404359    True      True    True       ...                             True
# 2405586    True      True    True       ...                             True
# 2406338    True      True    True       ...                             True
# 2412602    True      True    True       ...                             True
# 2415833    True      True    True       ...                             True
# 2415911    True      True    True       ...                             True
# 2416561    True      True    True       ...                             True
# 2417205    True      True    True       ...                             True
# 2418891    True      True    True       ...                             True
# 2419465    True      True    True       ...                             True
# 2422126    True      True    True       ...                             True
# 2422921    True      True    True       ...                             True
# 2425243    True      True    True       ...                             True
# 2428854    True      True    True       ...                             True
#
#          advertiser_1458  advertiser_2259  advertiser_2261  advertiser_2821  \
# 367179              True             True             True             True
# 1858024             True             True             True             True
# 54000               True             True             True             True
# 1073484             True             True             True             True
# 1185737             True             True             True             True
# 115944              True             True             True             True
# 592831              True             True             True             True
# 2080586             True             True             True             True
# 1860949             True             True             True             True
# 1724755             True             True             True             True
# 1630318             True             True             True             True
# 2088154             True             True             True             True
# 2004240             True             True             True             True
# 1617647             True             True             True             True
# 2397981             True             True             True             True
# 442932              True             True             True             True
# 350514              True             True             True             True
# 1278275             True             True             True             True
# 949163              True             True             True             True
# 474078              True             True             True             True
# 583089              True             True             True             True
# 868516              True             True             True             True
# 1899600             True             True             True             True
# 1208562             True             True             True             True
# 1370098             True             True             True             True
# 719393              True             True             True             True
# 2377190             True             True             True             True
# 2097978             True             True             True             True
# 1233293             True             True             True             True
# 749998              True             True             True             True
# ...                  ...              ...              ...              ...
# 2380677             True             True             True             True
# 2381907             True             True             True             True
# 2382324             True             True             True             True
# 2385688             True             True             True             True
# 2385798             True             True             True             True
# 2387011             True             True             True             True
# 2387360             True             True             True             True
# 2389704             True             True             True             True
# 2391471             True             True             True             True
# 2391894             True             True             True             True
# 2393079             True             True             True             True
# 2395842             True             True             True             True
# 2399896             True             True             True             True
# 2400875             True             True             True             True
# 2403309             True             True             True             True
# 2404304             True             True             True             True
# 2404359             True             True             True             True
# 2405586             True             True             True             True
# 2406338             True             True             True             True
# 2412602             True             True             True             True
# 2415833             True             True             True             True
# 2415911             True             True             True             True
# 2416561             True             True             True             True
# 2417205             True             True             True             True
# 2418891             True             True             True             True
# 2419465             True             True             True             True
# 2422126             True             True             True             True
# 2422921             True             True             True             True
# 2425243             True             True             True             True
# 2428854             True             True             True             True
#
#          advertiser_2997  advertiser_3358  advertiser_3386  advertiser_3427  \
# 367179              True             True             True             True
# 1858024             True             True             True             True
# 54000               True             True             True             True
# 1073484             True             True             True             True
# 1185737             True             True             True             True
# 115944              True             True             True             True
# 592831              True             True             True             True
# 2080586             True             True             True             True
# 1860949             True             True             True             True
# 1724755             True             True             True             True
# 1630318             True             True             True             True
# 2088154             True             True             True             True
# 2004240             True             True             True             True
# 1617647             True             True             True             True
# 2397981             True             True             True             True
# 442932              True             True             True             True
# 350514              True             True             True             True
# 1278275             True             True             True             True
# 949163              True             True             True             True
# 474078              True             True             True             True
# 583089              True             True             True             True
# 868516              True             True             True             True
# 1899600             True             True             True             True
# 1208562             True             True             True             True
# 1370098             True             True             True             True
# 719393              True             True             True             True
# 2377190             True             True             True             True
# 2097978             True             True             True             True
# 1233293             True             True             True             True
# 749998              True             True             True             True
# ...                  ...              ...              ...              ...
# 2380677             True             True             True             True
# 2381907             True             True             True             True
# 2382324             True             True             True             True
# 2385688             True             True             True             True
# 2385798             True             True             True             True
# 2387011             True             True             True             True
# 2387360             True             True             True             True
# 2389704             True             True             True             True
# 2391471             True             True             True             True
# 2391894             True             True             True             True
# 2393079             True             True             True             True
# 2395842             True             True             True             True
# 2399896             True             True             True             True
# 2400875             True             True             True             True
# 2403309             True             True             True             True
# 2404304             True             True             True             True
# 2404359             True             True             True             True
# 2405586             True             True             True             True
# 2406338             True             True             True             True
# 2412602             True             True             True             True
# 2415833             True             True             True             True
# 2415911             True             True             True             True
# 2416561             True             True             True             True
# 2417205             True             True             True             True
# 2418891             True             True             True             True
# 2419465             True             True             True             True
# 2422126             True             True             True             True
# 2422921             True             True             True             True
# 2425243             True             True             True             True
# 2428854             True             True             True             True
#
#          advertiser_3476
# 367179              True
# 1858024             True
# 54000               True
# 1073484             True
# 1185737             True
# 115944              True
# 592831              True
# 2080586             True
# 1860949             True
# 1724755             True
# 1630318             True
# 2088154             True
# 2004240             True
# 1617647             True
# 2397981             True
# 442932              True
# 350514              True
# 1278275             True
# 949163              True
# 474078              True
# 583089              True
# 868516              True
# 1899600             True
# 1208562             True
# 1370098             True
# 719393              True
# 2377190             True
# 2097978             True
# 1233293             True
# 749998              True
# ...                  ...
# 2380677             True
# 2381907             True
# 2382324             True
# 2385688             True
# 2385798             True
# 2387011             True
# 2387360             True
# 2389704             True
# 2391471             True
# 2391894             True
# 2393079             True
# 2395842             True
# 2399896             True
# 2400875             True
# 2403309             True
# 2404304             True
# 2404359             True
# 2405586             True
# 2406338             True
# 2412602             True
# 2415833             True
# 2415911             True
# 2416561             True
# 2417205             True
# 2418891             True
# 2419465             True
# 2422126             True
# 2422921             True
# 2425243             True
# 2428854             True
#
# [3586 rows x 476 columns]
#         click  weekday  hour  slotprice  bidprice  payprice  OS_android  \
# 0        True     True  True       True      True      True        True
# 1        True     True  True       True      True      True        True
# 2        True     True  True       True      True      True        True
# 3        True     True  True       True      True      True        True
# 4        True     True  True       True      True      True        True
# 5        True     True  True       True      True      True        True
# 6        True     True  True       True      True      True        True
# 7        True     True  True       True      True      True        True
# 8        True     True  True       True      True      True        True
# 9        True     True  True       True      True      True        True
# 10       True     True  True       True      True      True        True
# 11       True     True  True       True      True      True        True
# 12       True     True  True       True      True      True        True
# 13       True     True  True       True      True      True        True
# 14       True     True  True       True      True      True        True
# 15       True     True  True       True      True      True        True
# 16       True     True  True       True      True      True        True
# 17       True     True  True       True      True      True        True
# 18       True     True  True       True      True      True        True
# 19       True     True  True       True      True      True        True
# 20       True     True  True       True      True      True        True
# 21       True     True  True       True      True      True        True
# 22       True     True  True       True      True      True        True
# 23       True     True  True       True      True      True        True
# 24       True     True  True       True      True      True        True
# 25       True     True  True       True      True      True        True
# 26       True     True  True       True      True      True        True
# 27       True     True  True       True      True      True        True
# 28       True     True  True       True      True      True        True
# 29       True     True  True       True      True      True        True
# ...       ...      ...   ...        ...       ...       ...         ...
# 303895   True     True  True       True      True      True        True
# 303896   True     True  True       True      True      True        True
# 303897   True     True  True       True      True      True        True
# 303898   True     True  True       True      True      True        True
# 303899   True     True  True       True      True      True        True
# 303900   True     True  True       True      True      True        True
# 303901   True     True  True       True      True      True        True
# 303902   True     True  True       True      True      True        True
# 303903   True     True  True       True      True      True        True
# 303904   True     True  True       True      True      True        True
# 303905   True     True  True       True      True      True        True
# 303906   True     True  True       True      True      True        True
# 303907   True     True  True       True      True      True        True
# 303908   True     True  True       True      True      True        True
# 303909   True     True  True       True      True      True        True
# 303910   True     True  True       True      True      True        True
# 303911   True     True  True       True      True      True        True
# 303912   True     True  True       True      True      True        True
# 303913   True     True  True       True      True      True        True
# 303914   True     True  True       True      True      True        True
# 303915   True     True  True       True      True      True        True
# 303916   True     True  True       True      True      True        True
# 303917   True     True  True       True      True      True        True
# 303918   True     True  True       True      True      True        True
# 303919   True     True  True       True      True      True        True
# 303920   True     True  True       True      True      True        True
# 303921   True     True  True       True      True      True        True
# 303922   True     True  True       True      True      True        True
# 303923   True     True  True       True      True      True        True
# 303924   True     True  True       True      True      True        True
#
#         OS_ios  OS_linux  OS_mac       ...         slotvisibility_ThirdView  \
# 0         True      True    True       ...                             True
# 1         True      True    True       ...                             True
# 2         True      True    True       ...                             True
# 3         True      True    True       ...                             True
# 4         True      True    True       ...                             True
# 5         True      True    True       ...                             True
# 6         True      True    True       ...                             True
# 7         True      True    True       ...                             True
# 8         True      True    True       ...                             True
# 9         True      True    True       ...                             True
# 10        True      True    True       ...                             True
# 11        True      True    True       ...                             True
# 12        True      True    True       ...                             True
# 13        True      True    True       ...                             True
# 14        True      True    True       ...                             True
# 15        True      True    True       ...                             True
# 16        True      True    True       ...                             True
# 17        True      True    True       ...                             True
# 18        True      True    True       ...                             True
# 19        True      True    True       ...                             True
# 20        True      True    True       ...                             True
# 21        True      True    True       ...                             True
# 22        True      True    True       ...                             True
# 23        True      True    True       ...                             True
# 24        True      True    True       ...                             True
# 25        True      True    True       ...                             True
# 26        True      True    True       ...                             True
# 27        True      True    True       ...                             True
# 28        True      True    True       ...                             True
# 29        True      True    True       ...                             True
# ...        ...       ...     ...       ...                              ...
# 303895    True      True    True       ...                             True
# 303896    True      True    True       ...                             True
# 303897    True      True    True       ...                             True
# 303898    True      True    True       ...                             True
# 303899    True      True    True       ...                             True
# 303900    True      True    True       ...                             True
# 303901    True      True    True       ...                             True
# 303902    True      True    True       ...                             True
# 303903    True      True    True       ...                             True
# 303904    True      True    True       ...                             True
# 303905    True      True    True       ...                             True
# 303906    True      True    True       ...                             True
# 303907    True      True    True       ...                             True
# 303908    True      True    True       ...                             True
# 303909    True      True    True       ...                             True
# 303910    True      True    True       ...                             True
# 303911    True      True    True       ...                             True
# 303912    True      True    True       ...                             True
# 303913    True      True    True       ...                             True
# 303914    True      True    True       ...                             True
# 303915    True      True    True       ...                             True
# 303916    True      True    True       ...                             True
# 303917    True      True    True       ...                             True
# 303918    True      True    True       ...                             True
# 303919    True      True    True       ...                             True
# 303920    True      True    True       ...                             True
# 303921    True      True    True       ...                             True
# 303922    True      True    True       ...                             True
# 303923    True      True    True       ...                             True
# 303924    True      True    True       ...                             True
#
#         advertiser_1458  advertiser_2259  advertiser_2261  advertiser_2821  \
# 0                  True             True             True             True
# 1                  True             True             True             True
# 2                  True             True             True             True
# 3                  True             True             True             True
# 4                  True             True             True             True
# 5                  True             True             True             True
# 6                  True             True             True             True
# 7                  True             True             True             True
# 8                  True             True             True             True
# 9                  True             True             True             True
# 10                 True             True             True             True
# 11                 True             True             True             True
# 12                 True             True             True             True
# 13                 True             True             True             True
# 14                 True             True             True             True
# 15                 True             True             True             True
# 16                 True             True             True             True
# 17                 True             True             True             True
# 18                 True             True             True             True
# 19                 True             True             True             True
# 20                 True             True             True             True
# 21                 True             True             True             True
# 22                 True             True             True             True
# 23                 True             True             True             True
# 24                 True             True             True             True
# 25                 True             True             True             True
# 26                 True             True             True             True
# 27                 True             True             True             True
# 28                 True             True             True             True
# 29                 True             True             True             True
# ...                 ...              ...              ...              ...
# 303895             True             True             True             True
# 303896             True             True             True             True
# 303897             True             True             True             True
# 303898             True             True             True             True
# 303899             True             True             True             True
# 303900             True             True             True             True
# 303901             True             True             True             True
# 303902             True             True             True             True
# 303903             True             True             True             True
# 303904             True             True             True             True
# 303905             True             True             True             True
# 303906             True             True             True             True
# 303907             True             True             True             True
# 303908             True             True             True             True
# 303909             True             True             True             True
# 303910             True             True             True             True
# 303911             True             True             True             True
# 303912             True             True             True             True
# 303913             True             True             True             True
# 303914             True             True             True             True
# 303915             True             True             True             True
# 303916             True             True             True             True
# 303917             True             True             True             True
# 303918             True             True             True             True
# 303919             True             True             True             True
# 303920             True             True             True             True
# 303921             True             True             True             True
# 303922             True             True             True             True
# 303923             True             True             True             True
# 303924             True             True             True             True
#
#         advertiser_2997  advertiser_3358  advertiser_3386  advertiser_3427  \
# 0                  True             True             True             True
# 1                  True             True             True             True
# 2                  True             True             True             True
# 3                  True             True             True             True
# 4                  True             True             True             True
# 5                  True             True             True             True
# 6                  True             True             True             True
# 7                  True             True             True             True
# 8                  True             True             True             True
# 9                  True             True             True             True
# 10                 True             True             True             True
# 11                 True             True             True             True
# 12                 True             True             True             True
# 13                 True             True             True             True
# 14                 True             True             True             True
# 15                 True             True             True             True
# 16                 True             True             True             True
# 17                 True             True             True             True
# 18                 True             True             True             True
# 19                 True             True             True             True
# 20                 True             True             True             True
# 21                 True             True             True             True
# 22                 True             True             True             True
# 23                 True             True             True             True
# 24                 True             True             True             True
# 25                 True             True             True             True
# 26                 True             True             True             True
# 27                 True             True             True             True
# 28                 True             True             True             True
# 29                 True             True             True             True
# ...                 ...              ...              ...              ...
# 303895             True             True             True             True
# 303896             True             True             True             True
# 303897             True             True             True             True
# 303898             True             True             True             True
# 303899             True             True             True             True
# 303900             True             True             True             True
# 303901             True             True             True             True
# 303902             True             True             True             True
# 303903             True             True             True             True
# 303904             True             True             True             True
# 303905             True             True             True             True
# 303906             True             True             True             True
# 303907             True             True             True             True
# 303908             True             True             True             True
# 303909             True             True             True             True
# 303910             True             True             True             True
# 303911             True             True             True             True
# 303912             True             True             True             True
# 303913             True             True             True             True
# 303914             True             True             True             True
# 303915             True             True             True             True
# 303916             True             True             True             True
# 303917             True             True             True             True
# 303918             True             True             True             True
# 303919             True             True             True             True
# 303920             True             True             True             True
# 303921             True             True             True             True
# 303922             True             True             True             True
# 303923             True             True             True             True
# 303924             True             True             True             True
#
#         advertiser_3476
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# 5                  True
# 6                  True
# 7                  True
# 8                  True
# 9                  True
# 10                 True
# 11                 True
# 12                 True
# 13                 True
# 14                 True
# 15                 True
# 16                 True
# 17                 True
# 18                 True
# 19                 True
# 20                 True
# 21                 True
# 22                 True
# 23                 True
# 24                 True
# 25                 True
# 26                 True
# 27                 True
# 28                 True
# 29                 True
# ...                 ...
# 303895             True
# 303896             True
# 303897             True
# 303898             True
# 303899             True
# 303900             True
# 303901             True
# 303902             True
# 303903             True
# 303904             True
# 303905             True
# 303906             True
# 303907             True
# 303908             True
# 303909             True
# 303910             True
# 303911             True
# 303912             True
# 303913             True
# 303914             True
# 303915             True
# 303916             True
# 303917             True
# 303918             True
# 303919             True
# 303920             True
# 303921             True
# 303922             True
# 303923             True
# 303924             True
#
# [303925 rows x 476 columns]
#         weekday  hour  slotprice  OS_android  OS_ios  OS_linux  OS_mac  \
# 0          True  True       True        True    True      True    True
# 1          True  True       True        True    True      True    True
# 2          True  True       True        True    True      True    True
# 3          True  True       True        True    True      True    True
# 4          True  True       True        True    True      True    True
# 5          True  True       True        True    True      True    True
# 6          True  True       True        True    True      True    True
# 7          True  True       True        True    True      True    True
# 8          True  True       True        True    True      True    True
# 9          True  True       True        True    True      True    True
# 10         True  True       True        True    True      True    True
# 11         True  True       True        True    True      True    True
# 12         True  True       True        True    True      True    True
# 13         True  True       True        True    True      True    True
# 14         True  True       True        True    True      True    True
# 15         True  True       True        True    True      True    True
# 16         True  True       True        True    True      True    True
# 17         True  True       True        True    True      True    True
# 18         True  True       True        True    True      True    True
# 19         True  True       True        True    True      True    True
# 20         True  True       True        True    True      True    True
# 21         True  True       True        True    True      True    True
# 22         True  True       True        True    True      True    True
# 23         True  True       True        True    True      True    True
# 24         True  True       True        True    True      True    True
# 25         True  True       True        True    True      True    True
# 26         True  True       True        True    True      True    True
# 27         True  True       True        True    True      True    True
# 28         True  True       True        True    True      True    True
# 29         True  True       True        True    True      True    True
# ...         ...   ...        ...         ...     ...       ...     ...
# 303345     True  True       True        True    True      True    True
# 303346     True  True       True        True    True      True    True
# 303347     True  True       True        True    True      True    True
# 303348     True  True       True        True    True      True    True
# 303349     True  True       True        True    True      True    True
# 303350     True  True       True        True    True      True    True
# 303351     True  True       True        True    True      True    True
# 303352     True  True       True        True    True      True    True
# 303353     True  True       True        True    True      True    True
# 303354     True  True       True        True    True      True    True
# 303355     True  True       True        True    True      True    True
# 303356     True  True       True        True    True      True    True
# 303357     True  True       True        True    True      True    True
# 303358     True  True       True        True    True      True    True
# 303359     True  True       True        True    True      True    True
# 303360     True  True       True        True    True      True    True
# 303361     True  True       True        True    True      True    True
# 303362     True  True       True        True    True      True    True
# 303363     True  True       True        True    True      True    True
# 303364     True  True       True        True    True      True    True
# 303365     True  True       True        True    True      True    True
# 303366     True  True       True        True    True      True    True
# 303367     True  True       True        True    True      True    True
# 303368     True  True       True        True    True      True    True
# 303369     True  True       True        True    True      True    True
# 303370     True  True       True        True    True      True    True
# 303371     True  True       True        True    True      True    True
# 303372     True  True       True        True    True      True    True
# 303373     True  True       True        True    True      True    True
# 303374     True  True       True        True    True      True    True
#
#         OS_other  OS_windows  browser_chrome       ...         \
# 0           True        True            True       ...
# 1           True        True            True       ...
# 2           True        True            True       ...
# 3           True        True            True       ...
# 4           True        True            True       ...
# 5           True        True            True       ...
# 6           True        True            True       ...
# 7           True        True            True       ...
# 8           True        True            True       ...
# 9           True        True            True       ...
# 10          True        True            True       ...
# 11          True        True            True       ...
# 12          True        True            True       ...
# 13          True        True            True       ...
# 14          True        True            True       ...
# 15          True        True            True       ...
# 16          True        True            True       ...
# 17          True        True            True       ...
# 18          True        True            True       ...
# 19          True        True            True       ...
# 20          True        True            True       ...
# 21          True        True            True       ...
# 22          True        True            True       ...
# 23          True        True            True       ...
# 24          True        True            True       ...
# 25          True        True            True       ...
# 26          True        True            True       ...
# 27          True        True            True       ...
# 28          True        True            True       ...
# 29          True        True            True       ...
# ...          ...         ...             ...       ...
# 303345      True        True            True       ...
# 303346      True        True            True       ...
# 303347      True        True            True       ...
# 303348      True        True            True       ...
# 303349      True        True            True       ...
# 303350      True        True            True       ...
# 303351      True        True            True       ...
# 303352      True        True            True       ...
# 303353      True        True            True       ...
# 303354      True        True            True       ...
# 303355      True        True            True       ...
# 303356      True        True            True       ...
# 303357      True        True            True       ...
# 303358      True        True            True       ...
# 303359      True        True            True       ...
# 303360      True        True            True       ...
# 303361      True        True            True       ...
# 303362      True        True            True       ...
# 303363      True        True            True       ...
# 303364      True        True            True       ...
# 303365      True        True            True       ...
# 303366      True        True            True       ...
# 303367      True        True            True       ...
# 303368      True        True            True       ...
# 303369      True        True            True       ...
# 303370      True        True            True       ...
# 303371      True        True            True       ...
# 303372      True        True            True       ...
# 303373      True        True            True       ...
# 303374      True        True            True       ...
#
#         slotvisibility_ThirdView  advertiser_1458  advertiser_2259  \
# 0                           True             True             True
# 1                           True             True             True
# 2                           True             True             True
# 3                           True             True             True
# 4                           True             True             True
# 5                           True             True             True
# 6                           True             True             True
# 7                           True             True             True
# 8                           True             True             True
# 9                           True             True             True
# 10                          True             True             True
# 11                          True             True             True
# 12                          True             True             True
# 13                          True             True             True
# 14                          True             True             True
# 15                          True             True             True
# 16                          True             True             True
# 17                          True             True             True
# 18                          True             True             True
# 19                          True             True             True
# 20                          True             True             True
# 21                          True             True             True
# 22                          True             True             True
# 23                          True             True             True
# 24                          True             True             True
# 25                          True             True             True
# 26                          True             True             True
# 27                          True             True             True
# 28                          True             True             True
# 29                          True             True             True
# ...                          ...              ...              ...
# 303345                      True             True             True
# 303346                      True             True             True
# 303347                      True             True             True
# 303348                      True             True             True
# 303349                      True             True             True
# 303350                      True             True             True
# 303351                      True             True             True
# 303352                      True             True             True
# 303353                      True             True             True
# 303354                      True             True             True
# 303355                      True             True             True
# 303356                      True             True             True
# 303357                      True             True             True
# 303358                      True             True             True
# 303359                      True             True             True
# 303360                      True             True             True
# 303361                      True             True             True
# 303362                      True             True             True
# 303363                      True             True             True
# 303364                      True             True             True
# 303365                      True             True             True
# 303366                      True             True             True
# 303367                      True             True             True
# 303368                      True             True             True
# 303369                      True             True             True
# 303370                      True             True             True
# 303371                      True             True             True
# 303372                      True             True             True
# 303373                      True             True             True
# 303374                      True             True             True
#
#         advertiser_2261  advertiser_2821  advertiser_2997  advertiser_3358  \
# 0                  True             True             True             True
# 1                  True             True             True             True
# 2                  True             True             True             True
# 3                  True             True             True             True
# 4                  True             True             True             True
# 5                  True             True             True             True
# 6                  True             True             True             True
# 7                  True             True             True             True
# 8                  True             True             True             True
# 9                  True             True             True             True
# 10                 True             True             True             True
# 11                 True             True             True             True
# 12                 True             True             True             True
# 13                 True             True             True             True
# 14                 True             True             True             True
# 15                 True             True             True             True
# 16                 True             True             True             True
# 17                 True             True             True             True
# 18                 True             True             True             True
# 19                 True             True             True             True
# 20                 True             True             True             True
# 21                 True             True             True             True
# 22                 True             True             True             True
# 23                 True             True             True             True
# 24                 True             True             True             True
# 25                 True             True             True             True
# 26                 True             True             True             True
# 27                 True             True             True             True
# 28                 True             True             True             True
# 29                 True             True             True             True
# ...                 ...              ...              ...              ...
# 303345             True             True             True             True
# 303346             True             True             True             True
# 303347             True             True             True             True
# 303348             True             True             True             True
# 303349             True             True             True             True
# 303350             True             True             True             True
# 303351             True             True             True             True
# 303352             True             True             True             True
# 303353             True             True             True             True
# 303354             True             True             True             True
# 303355             True             True             True             True
# 303356             True             True             True             True
# 303357             True             True             True             True
# 303358             True             True             True             True
# 303359             True             True             True             True
# 303360             True             True             True             True
# 303361             True             True             True             True
# 303362             True             True             True             True
# 303363             True             True             True             True
# 303364             True             True             True             True
# 303365             True             True             True             True
# 303366             True             True             True             True
# 303367             True             True             True             True
# 303368             True             True             True             True
# 303369             True             True             True             True
# 303370             True             True             True             True
# 303371             True             True             True             True
# 303372             True             True             True             True
# 303373             True             True             True             True
# 303374             True             True             True             True
#
#         advertiser_3386  advertiser_3427  advertiser_3476
# 0                  True             True             True
# 1                  True             True             True
# 2                  True             True             True
# 3                  True             True             True
# 4                  True             True             True
# 5                  True             True             True
# 6                  True             True             True
# 7                  True             True             True
# 8                  True             True             True
# 9                  True             True             True
# 10                 True             True             True
# 11                 True             True             True
# 12                 True             True             True
# 13                 True             True             True
# 14                 True             True             True
# 15                 True             True             True
# 16                 True             True             True
# 17                 True             True             True
# 18                 True             True             True
# 19                 True             True             True
# 20                 True             True             True
# 21                 True             True             True
# 22                 True             True             True
# 23                 True             True             True
# 24                 True             True             True
# 25                 True             True             True
# 26                 True             True             True
# 27                 True             True             True
# 28                 True             True             True
# 29                 True             True             True
# ...                 ...              ...              ...
# 303345             True             True             True
# 303346             True             True             True
# 303347             True             True             True
# 303348             True             True             True
# 303349             True             True             True
# 303350             True             True             True
# 303351             True             True             True
# 303352             True             True             True
# 303353             True             True             True
# 303354             True             True             True
# 303355             True             True             True
# 303356             True             True             True
# 303357             True             True             True
# 303358             True             True             True
# 303359             True             True             True
# 303360             True             True             True
# 303361             True             True             True
# 303362             True             True             True
# 303363             True             True             True
# 303364             True             True             True
# 303365             True             True             True
# 303366             True             True             True
# 303367             True             True             True
# 303368             True             True             True
# 303369             True             True             True
# 303370             True             True             True
# 303371             True             True             True
# 303372             True             True             True
# 303373             True             True             True
# 303374             True             True             True
#
# [303375 rows x 473 columns]
